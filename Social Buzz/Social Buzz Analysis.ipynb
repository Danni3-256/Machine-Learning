# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Social Buzz Final.csv')
data.head()
# Out:
#                                 User ID           Name         Email  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8      Gary Hill  GHbnuothhymw
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8      Gary Hill  GHbnuothhymw
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8      Gary Hill  GHbnuothhymw
# 3  5d454588-283d-459d-915d-c48a2cb4c27f  Richard Smith  RS@gmail.com
# 4  5d454588-283d-459d-915d-c48a2cb4c27f  Richard Smith  RS@gmail.com
#
#     Interests  Age                                          Address  \
# 0         NaN   41      6208 Wright Mountains\nBryantfurt, AR 02531
# 1         NaN   41      6208 Wright Mountains\nBryantfurt, AR 02531
# 2         NaN   41      6208 Wright Mountains\nBryantfurt, AR 02531
# 3  ['travel']    6  00358 Heather Gardens\nLake Heidiview, OH 42464
# 4  ['travel']    6  00358 Heather Gardens\nLake Heidiview, OH 42464
#
#       Device  Duration  Category Reaction        Date Sentiment  Score
# ...

# %%
data.shape
# Out:
# (44857, 13)

# %%
data.isnull().sum()
# Out:
# User ID         0
# Name            0
# Email           0
# Interests     485
# Age             0
# Address         0
# Device          0
# Duration        0
# Category     2449
# Reaction        0
# Date            0
# Sentiment       0
# Score           0
# dtype: int64

# %%
data['Interests'].fillna('Unknown', inplace = True)
data['Category'].fillna('Not Available', inplace = True)
data.head()
# Out:
#                                 User ID           Name         Email  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8      Gary Hill  GHbnuothhymw
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8      Gary Hill  GHbnuothhymw
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8      Gary Hill  GHbnuothhymw
# 3  5d454588-283d-459d-915d-c48a2cb4c27f  Richard Smith  RS@gmail.com
# 4  5d454588-283d-459d-915d-c48a2cb4c27f  Richard Smith  RS@gmail.com
#
#     Interests  Age                                          Address  \
# 0     Unknown   41      6208 Wright Mountains\nBryantfurt, AR 02531
# 1     Unknown   41      6208 Wright Mountains\nBryantfurt, AR 02531
# 2     Unknown   41      6208 Wright Mountains\nBryantfurt, AR 02531
# 3  ['travel']    6  00358 Heather Gardens\nLake Heidiview, OH 42464
# 4  ['travel']    6  00358 Heather Gardens\nLake Heidiview, OH 42464
#
#       Device  Duration  Category Reaction        Date Sentiment  Score
# ...

# %%
data.isnull().sum()
# Out:
# User ID      0
# Name         0
# Email        0
# Interests    0
# Age          0
# Address      0
# Device       0
# Duration     0
# Category     0
# Reaction     0
# Date         0
# Sentiment    0
# Score        0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#                                     User ID              Name         Email  \
# 2686   de050611-e926-43bb-b1ea-502d8bd25bfc        Karen Rios  KR@gmail.com
# 2687   de050611-e926-43bb-b1ea-502d8bd25bfc        Karen Rios  KR@gmail.com
# 2688   de050611-e926-43bb-b1ea-502d8bd25bfc        Karen Rios  KR@gmail.com
# 4625   e09aa625-3db7-49bd-be09-9aaa0c86a8bf   Matthew Perkins  MP@gmail.com
# 4626   e09aa625-3db7-49bd-be09-9aaa0c86a8bf   Matthew Perkins  MP@gmail.com
# ...                                     ...               ...           ...
# 44114  311d7214-711f-4f66-bc9a-e835fa54ffb6  Sandra Gutierrez  SG@gmail.com
# 44115  311d7214-711f-4f66-bc9a-e835fa54ffb6  Sandra Gutierrez  SG@gmail.com
# 44116  311d7214-711f-4f66-bc9a-e835fa54ffb6  Sandra Gutierrez  SG@gmail.com
# 44117  311d7214-711f-4f66-bc9a-e835fa54ffb6  Sandra Gutierrez  SG@gmail.com
# 44471  70848bd7-6cd5-4686-b22b-a9afb05541a5    Shirley Yamada  SY@gmail.com
#
#                                        Interests  Age  \
# ...

# %%
new_data = data.drop_duplicates()

# %%
new_data[new_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User ID, Name, Email, Interests, Age, Address, Device, Duration, Category, Reaction, Date, Sentiment, Score]
# Index: []

# %%
new_data.shape
# Out:
# (44634, 13)

# %%
new_data.head(1)
# Out:
#                                 User ID       Name         Email Interests  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw   Unknown
#
#    Age                                      Address     Device  Duration  \
# 0   41  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11
#
#   Category Reaction        Date Sentiment  Score
# 0   soccer   scared  20/09/2020  negative     15

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
new_data['Category'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
new_data['Category'].unique()
# Out:
# array(['soccer', 'fitness', 'animals', 'cooking', 'studying', 'Studying',
#        'education', 'travel', 'public speaking', 'healthy eating', 'food',
#        'dogs', 'tennis', 'Food', 'technology', 'Education', 'veganism',
#        'Not Available', 'culture', '"public speaking"', 'science',
#        '"science"', '"soccer"', '"tennis"', '"studying"', 'Culture',
#        'Technology', '"culture"', 'Veganism', 'Animals', '"dogs"',
#        'Public Speaking', 'Fitness', 'Science', '"food"', 'Soccer',
#        'Healthy Eating', '"animals"', '"cooking"', 'Travel',
#        '"technology"', '"veganism"'], dtype=object)

# %%
new_data['Category'].value_counts()
# Out:
# technology           2925
# travel               2875
# animals              2776
# science              2684
# healthy eating       2658
# fitness              2607
# culture              2593
# food                 2591
# cooking              2571
# tennis               2537
# soccer               2473
# Not Available        2446
# education            2357
# dogs                 2321
# studying             2259
# veganism             2065
# public speaking      2018
# Fitness               218
# "soccer"              135
# Science               125
# Animals               125
# "culture"             118
# "dogs"                 98
# Travel                 96
# Food                   93
# Studying               88
# Soccer                 80
# Education              76
# Technology             55
# "technology"           54
# "veganism"             50
# Healthy Eating         47
# "food"                 46
# "science"              46
# "animals"              45
# ...

# %%
new_data['Sentiment'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  6.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.2  1.0  1.0
# 2      Bournemouth  ...  Match Report    NaN  20.0   7.0  15.6  0.0  0.0
# 3    Newcastle Utd  ...  Match Report    NaN  22.0  10.0  15.1  1.0  0.0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  13.1  0.0  0.0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.1  0.0  0.0
#
#   pkatt  season             team
# 1   1.0    2023  Manchester City
# 2   0.0    2023  Manchester City
# 3   0.0    2023  Manchester City
# 4   0.0    2023  Manchester City
# 5   0.0    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (51, 27)

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 8
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          51 non-null     object
#  1   time          51 non-null     object
#  2   comp          51 non-null     object
#  3   round         51 non-null     object
#  4   day           51 non-null     object
#  5   venue         51 non-null     object
#  6   result        51 non-null     object
#  7   gf            51 non-null     float64
#  8   ga            51 non-null     float64
#  9   opponent      51 non-null     object
#  10  xg            46 non-null     float64
#  11  xga           46 non-null     float64
#  12  poss          46 non-null     float64
#  13  attendance    46 non-null     float64
#  14  captain       51 non-null     object
#  15  formation     51 non-null     object
#  16  referee       51 non-null     object
#  17  match report  51 non-null     object
#  18  notes         0 non-null      float64
#  19  sh            46 non-null     float64
#  20  sot           46 non-null     float64
#  21  dist          46 non-null     float64
#  22  fk            46 non-null     float64
#  23  pk            51 non-null     float64
#  24  pkatt         51 non-null     float64
#  25  season        51 non-null     int64
#  26  team          51 non-null     object
# dtypes: float64(13), int64(1), object(13)
# memory usage: 11.2+ KB

# %%
matches["team"].value_counts()
# Out:
# Manchester City      8
# Tottenham Hotspur    8
# Leicester City       8
# Nottingham Forest    8
# Chelsea              7
# Liverpool            7
# Shakhtar Donetsk     5
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1    7
# Matchweek 2    7
# Matchweek 3    7
# Matchweek 4    7
# Matchweek 5    7
# Matchweek 6    6
# Matchweek 9    6
# Matchweek 8    4
# Name: round, dtype: int64

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
mat
# 7  2022-09-17  17:30  Matchweek 8  Sat  Away      L  2.0  6.0
# 8  2022-10-03  20:00  Matchweek 9  Mon  Home      W  4.0  0.0
# 0  2022-08-06  15:00  Matchweek 1  Sat  Away      L  0.0  2.0
# 1  2022-08-14  14:00  Matchweek 2  Sun  Home      W  1.0  0.0
# 2  2022-08-20  15:00  Matchweek 3  Sat  Away      D  1.0  1.0
# 4  2022-08-28  16:30  Matchweek 4  Sun  Home      L  0.0  2.0
# 5  2022-08-31  19:30  Matchweek 5  Wed  Away      L  0.0  6.0
# 6  2022-09-03  15:00  Matchweek 6  Sat  Home      L  2.0  3.0
# 7  2022-09-16  20:00  Matchweek 8  Fri  Home      L  2.0  3.0
# 8  2022-10-03  20:00  Matchweek 9  Mon  Away      L  0.0  4.0
#
#                     opponent   xg  ...  match report    sh   sot  dist   fk  \
# 1                   West Ham  2.3  ...  Match Report  13.0   1.0  18.2  1.0
# 2                Bournemouth  1.6  ...  Match Report  20.0   7.0  15.6  0.0
# 3              Newcastle Utd  2.7  ...  Match Report  22.0  10.0  15.1  1.0
# 4             Crystal Palace  2.5  ...  Match Report  18.0   5.0  13.1  0.0
# 5            Nott'ham Forest  3.7  ...  Match Report  17.0   9.0  14.1  0.0
# 6                Aston Villa  1.4  ...  Match Report  13.0   4.0  15.7  1.0
# 9                     Wolves  1.4  ...  Match Report  15.0   7.0  18.8  0.0
# 10            Manchester Utd  2.9  ...  Match Report  22.0   9.0  13.5  1.0
# 0                    Everton  1.6  ...  Match Report  14.0   5.0  16.2  1.0
# 1                  Tottenham  1.4  ...  Match Report  16.0   3.0  16.7  0.0
# 2               Leeds United  0.7  ...  Match Report  14.0   3.0  18.8  0.0
# 3             Leicester City  1.9  ...  Match Report   7.0   3.0  13.7  0.0
# 4                Southampton  1.2  ...  Match Report  10.0   4.0  13.8  0.0
# 5                   West Ham  0.8  ...  Match Report   8.0   3.0  16.3  0.0
# 8             Crystal Palace  1.4  ...  Match Report  13.0   3.0  14.0  0.0
# 0   FK Metalist 1925 Kharkiv  NaN  ...  Match Report   NaN   NaN   NaN  NaN
# 1         Kryvbas Kryvyi Rih  NaN  ...  Match Report   NaN   NaN   NaN  NaN
# 2                        Рух  NaN  ...  Match Report   NaN   NaN   NaN  NaN
# 4         Chornomorets Odesa  NaN  ...  Match Report   NaN   NaN   NaN  NaN
# 6        FK Metalist Kharkiv  NaN  ...  Match Report   NaN   NaN   NaN  NaN
# 1                     Fulham  1.9  ...  Match Report  11.0   3.0  11.8  0.0
# 2             Crystal Palace  1.7  ...  Match Report  24.0   4.0  17.1  0.0
# 3             Manchester Utd  1.5  ...  Match Report  17.0   5.0  14.5  0.0
# 4                Bournemouth  3.4  ...  Match Report  19.0  12.0  10.8  0.0
# 5              Newcastle Utd  1.5  ...  Match Report  23.0   6.0  17.4  0.0
# 6                    Everton  2.2  ...  Match Report  24.0   9.0  12.3  0.0
# 9                   Brighton  1.6  ...  Match Report  15.0   7.0  16.0  1.0
# 0                Southampton  1.5  ...  Match Report  18.0   7.0  15.8  0.0
# 1                    Chelsea  1.1  ...  Match Report  10.0   5.0  12.6  0.0
# 2                     Wolves  1.5  ...  Match Report  11.0   5.0  11.0  0.0
# 3            Nott'ham Forest  2.7  ...  Match Report  18.0   4.0  19.0  0.0
# 4                   West Ham  0.7  ...  Match Report  13.0   4.0  16.2  0.0
# 5                     Fulham  2.5  ...  Match Report  23.0  10.0  15.6  1.0
# 8             Leicester City  1.7  ...  Match Report  16.0  10.0  15.8  0.0
# 9                    Arsenal  1.5  ...  Match Report   6.0   2.0  18.8  0.0
# 0                  Brentford  0.6  ...  Match Report  14.0   5.0  22.2  0.0
# 1                    Arsenal  0.6  ...  Match Report   6.0   2.0  15.3  0.0
# 2                Southampton  0.3  ...  Match Report   6.0   1.0  17.1  1.0
# 4                    Chelsea  1.7  ...  Match Report  17.0   5.0  17.5  0.0
# 5             Manchester Utd  0.6  ...  Match Report  10.0   2.0  22.6  2.0
# 6                   Brighton  1.7  ...  Match Report   6.0   4.0  14.3  0.0
# 7                  Tottenham  1.7  ...  Match Report  18.0   6.0  21.6  0.0
# 8            Nott'ham Forest  1.1  ...  Match Report  16.0   6.0  16.8  1.0
# 0              Newcastle Utd  0.4  ...  Match Report   5.0   0.0  15.3  0.0
# 1                   West Ham  1.4  ...  Match Report  13.0   6.0  13.5  1.0
# 2                    Everton  1.0  ...  Match Report  14.0   5.0  18.7  1.0
# 4                  Tottenham  1.0  ...  Match Report  18.0   1.0  18.8  1.0
# 5            Manchester City  0.4  ...  Match Report   8.0   1.0  18.9  1.0
# 6                Bournemouth  1.3  ...  Match Report  10.0   2.0  16.9  0.0
# 7                     Fulham  1.4  ...  Match Report  11.0   3.0  15.8  1.0
# 8             Leicester City  1.2  ...  Match Report  10.0   3.0  15.0  0.0
#
#      pk pkatt  season               team  target
# 1   1.0   1.0    2023    Manchester City       1
# 2   0.0   0.0    2023    Manchester City       1
# 3   0.0   0.0    2023    Manchester City       0
# 4   0.0   0.0    2023    Manchester City       1
# 5   0.0   0.0    2023    Manchester City       1
# 6   0.0   0.0    2023    Manchester City       0
# 9   0.0   0.0    2023    Manchester City       1
# 10  0.0   0.0    2023    Manchester City       1
# 0   1.0   1.0    2023            Chelsea       1
# 1   0.0   0.0    2023            Chelsea       0
# 2   0.0   0.0    2023            Chelsea       0
# 3   0.0   0.0    2023            Chelsea       1
# 4   0.0   0.0    2023            Chelsea       0
# 5   0.0   0.0    2023            Chelsea       1
# 8   0.0   0.0    2023            Chelsea       1
# 0   0.0   0.0    2023   Shakhtar Donetsk       0
# 1   0.0   0.0    2023   Shakhtar Donetsk       1
# 2   0.0   0.0    2023   Shakhtar Donetsk       1
# 4   0.0   0.0    2023   Shakhtar Donetsk       1
# 6   0.0   1.0    2023   Shakhtar Donetsk       1
# 1   0.0   0.0    2022          Liverpool       0
# 2   0.0   0.0    2022          Liverpool       0
# 3   0.0   0.0    2022          Liverpool       0
# 4   0.0   0.0    2022          Liverpool       1
# 5   0.0   0.0    2022          Liverpool       1
# 6   0.0   0.0    2022          Liverpool       0
# 9   0.0   0.0    2022          Liverpool       0
# 0   0.0   0.0    2022  Tottenham Hotspur       1
# 1   0.0   0.0    2022  Tottenham Hotspur       0
# 2   0.0   0.0    2022  Tottenham Hotspur       1
# 2                        Рух  NaN  ...  NaN  0.0    0.0   2023
# 4         Chornomorets Odesa  NaN  ...  NaN  0.0    0.0   2023
# 6        FK Metalist Kharkiv  NaN  ...  NaN  0.0    1.0   2023
# 1                     Fulham  1.9  ...  0.0  0.0    0.0   2022
# 2             Crystal Palace  1.7  ...  0.0  0.0    0.0   2022
# 3             Manchester Utd  1.5  ...  0.0  0.0    0.0   2022
# 4                Bournemouth  3.4  ...  0.0  0.0    0.0   2022
# 5              Newcastle Utd  1.5  ...  0.0  0.0    0.0   2022
# 6                    Everton  2.2  ...  0.0  0.0    0.0   2022
# 9                   Brighton  1.6  ...  1.0  0.0    0.0   2022
# 0                Southampton  1.5  ...  0.0  0.0    0.0   2022
# 1                    Chelsea  1.1  ...  0.0  0.0    0.0   2022
# 2                     Wolves  1.5  ...  0.0  0.0    0.0   2022
# 3            Nott'ham Forest  2.7  ...  0.0  0.0    1.0   2022
# 4                   West Ham  0.7  ...  0.0  0.0    0.0   2022
# 5                     Fulham  2.5  ...  1.0  0.0    0.0   2022
# 8             Leicester City  1.7  ...  0.0  0.0    0.0   2022
# 9                    Arsenal  1.5  ...  0.0  1.0    1.0   2022
# 0                  Brentford  0.6  ...  0.0  0.0    0.0   2021
# 1                    Arsenal  0.6  ...  0.0  0.0    0.0   2021
# 2                Southampton  0.3  ...  1.0  0.0    0.0   2021
# 4                    Chelsea  1.7  ...  0.0  0.0    0.0   2021
# 5             Manchester Utd  0.6  ...  2.0  0.0    0.0   2021
# 6                   Brighton  1.7  ...  0.0  0.0    0.0   2021
# 7                  Tottenham  1.7  ...  0.0  1.0    1.0   2021
# 8            Nott'ham Forest  1.1  ...  1.0  0.0    0.0   2021
# 0              Newcastle Utd  0.4  ...  0.0  0.0    0.0   2021
# 1                   West Ham  1.4  ...  1.0  0.0    0.0   2021
# 2                    Everton  1.0  ...  1.0  0.0    0.0   2021
# 4                  Tottenham  1.0  ...  1.0  0.0    0.0   2021
# 5            Manchester City  0.4  ...  1.0  0.0    0.0   2021
# 6                Bournemouth  1.3  ...  0.0  1.0    1.0   2021
# 7                     Fulham  1.4  ...  1.0  0.0    0.0   2021
# 8             Leicester City  1.2  ...  0.0  0.0    0.0   2021
#
#                  team target venue_code  opp_code  hour  day_code
# 1     Manchester City      1          0        21    16         6
# 2     Manchester City      1          1         2    15         5
# 3     Manchester City      0          0        17    16         6
# 4     Manchester City      1          1         7    15         5
# 5     Manchester City      1          1        18    19         2
# 6     Manchester City      0          0         1    17         5
# 9     Manchester City      1          0        22    12         5
# 10    Manchester City      1          1        16    14         6
# 0             Chelsea      1          0         8    17         5
# 1             Chelsea      0          1        20    16         6
# 2             Chelsea      0          0        13    14         6
# 3             Chelsea      1          1        14    15         5
# 4             Chelsea      0          0        19    19         1
# 5             Chelsea      1          1        21    15         5
# 8             Chelsea      1          0         7    15         5
# 0    Shakhtar Donetsk      0          1         9    13         1
# 1    Shakhtar Donetsk      1          1        12    15         6
# 2    Shakhtar Donetsk      1          0        23    17         4
# 4    Shakhtar Donetsk      1          1         6    17         5
# 6    Shakhtar Donetsk      1          0        10    17         5
# 1           Liverpool      0          0        11    12         5
# 2           Liverpool      0          1         7    20         0
# 3           Liverpool      0          0        16    20         0
# 4           Liverpool      1          1         2    15         5
# 5           Liverpool      1          1        17    20         2
# 6           Liverpool      0          0         8    12         5
# 9           Liverpool      0          1         4    15         5
# 0   Tottenham Hotspur      1          1        19    15         5
# 1   Tottenham Hotspur      0          0         5    16         6
# 2   Tottenham Hotspur      1          1        22    12         5
# 3   Tottenham Hotspur      1          0        18    16         6
# 4   Tottenham Hotspur      0          0        21    19         2
# 5   Tottenham Hotspur      1          1        11    15         5
# 8   Tottenham Hotspur      1          1        14    17         5
# 9   Tottenham Hotspur      0          0         0    12         5
# 0      Leicester City      0          1         3    14         6
# 1      Leicester City      0          0         0    15         5
# 2      Leicester City      0          1        19    15         5
# 4      Leicester City      0          0         5    15         5
# 5      Leicester City      0          1        16    20         3
# 6      Leicester City      0          0         4    14         6
# 7      Leicester City      0          0        20    17         5
# 8      Leicester City      1          1        18    20         0
# 0   Nottingham Forest      0          0        17    15         5
# 1   Nottingham Forest      1          1        21    14         6
# 2   Nottingham Forest      0          0         8    15         5
# 4   Nottingham Forest      0          1        20    16         6
# 5   Nottingham Forest      0          0        15    19         2
# 6   Nottingham Forest      0          1         2    15         5
# 7   Nottingham Forest      0          1        11    20         4
# 8   Nottingham Forest      0          0        14    20         0
#
# [51 rows x 30 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
train.shape
# Out:
# (0, 30)

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
test.shape
# Out:
# (51, 30)

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 rf.fit(train[predictors], train["target"])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:909, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     907     n_samples = _num_samples(array)
#     908     if n_samples < ensure_min_samples:
# --> 909         raise ValueError(
#     910             "Found array with %d sample(s) (shape=%s) while a"
#     911             " minimum of %d is required%s."
#     912             % (n_samples, array.shape, ensure_min_samples, context)
#     913         )
#     915 if ensure_min_features > 0 and array.ndim == 2:
#     916     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 4)) while a minimum of 1 is required by RandomForestClassifier.

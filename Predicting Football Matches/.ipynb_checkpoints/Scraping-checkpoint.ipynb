# %%
import requests

# %%
standings_url = 'https://fbref.com/en/comps/12/La-Liga-Stats'

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting
# Out:
#   For Arsenal                                                               \
#          Date   Time            Comp        Round  Day Venue Result  GF GA
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W   2  0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4  2
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W   3  0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W   2  1
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   2  1
# 5  2022-09-04  16:30  Premier League  Matchweek 6  Sun  Away      L   1  3
# 6  2022-09-08  18:45       Europa Lg  Group stage  Thu  Away      W   2  1
# 7  2022-09-18  12:00  Premier League  Matchweek 8  Sun  Away      W   3  0
# 8  2022-10-01  12:30  Premier League  Matchweek 9  Sat  Home      W   3  1
# 9         NaN    NaN             NaN          NaN  NaN   NaN  8-0-1  22  9
#
#                    ... Standard             Expected                     \
#          Opponent  ...     Dist FK PK PKatt       xG  npxG npxG/Sh G-xG
# 0  Crystal Palace  ...     15.0  1  0     0      1.0   1.0    0.11  0.0
# 1  Leicester City  ...     12.6  0  0     0      2.6   2.6    0.14  1.4
# 2     Bournemouth  ...     14.6  0  0     0      1.8   1.8    0.14  1.2
# 3          Fulham  ...     16.6  1  0     0      2.4   2.4    0.10 -0.4
# 4     Aston Villa  ...     15.3  1  0     0      2.7   2.7    0.12 -0.7
# 5  Manchester Utd  ...     18.5  1  0     0      1.3   1.3    0.08 -0.3
# 6       ch Zürich  ...     15.0  0  0     0      1.8   1.8    0.10  0.2
# 7       Brentford  ...     17.1  0  0     0      1.0   1.0    0.07  2.0
# 8       Tottenham  ...     17.7  1  0     0      2.6   2.6    0.12  0.4
# 9             NaN  ...     15.9  5  0     0     17.1  17.1    0.11  3.9
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0     0.0        Match Report
# 1     1.4        Match Report
# 2     1.2        Match Report
# 3    -0.4        Match Report
# 4    -0.7        Match Report
# 5    -0.3        Match Report
# 6     0.2        Match Report
# 7     2.0        Match Report
# 8     0.4        Match Report
# 9     3.9                 NaN
#
# [10 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          Opponent  ...  Formation         Referee  Match Report  Notes  Sh  \
# 0  Crystal Palace  ...    4-2-3-1  Anthony Taylor  Match Report    NaN  10
# 1  Leicester City  ...    4-2-3-1  Darren England  Match Report    NaN  19
# 2     Bournemouth  ...    4-2-3-1    Craig Pawson  Match Report    NaN  14
# 3          Fulham  ...    4-2-3-1  Jarred Gillett  Match Report    NaN  23
# 4     Aston Villa  ...    4-2-3-1    Robert Jones  Match Report    NaN  22
#
#   SoT  Dist FK PK  PKatt
# 0   2  15.0  1  0      0
# 1   7  12.6  0  0      0
# 2   6  14.6  0  0      0
# 3   8  16.6  1  0      0
# 4   8  15.3  1  0      0
#
# [5 rows x 25 columns]

# %%
team_data.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt'],
#       dtype='object')

# %%
years = list(range(2022, 2019, -1))
all_matches = []

# %%
standings_url = 'https://fbref.com/en/matches/'

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 34

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp        round  day venue result   gf  \
# 1   2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0
# 2   2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0
# 3   2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D  3.0
# 4   2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0
# 5   2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  6.0
# 6   2022-09-03  17:30  Premier League  Matchweek 6  Sat  Away      D  1.0
# 9   2022-09-17  12:30  Premier League  Matchweek 8  Sat  Away      W  3.0
# 10  2022-10-02  14:00  Premier League  Matchweek 9  Sun  Home      W  6.0
# 0   2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W  1.0
# 1   2022-08-14  16:30  Premier League  Matchweek 2  Sun  Home      D  2.0
# 2   2022-08-21  14:00  Premier League  Matchweek 3  Sun  Away      L  0.0
# 3   2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  2.0
# 4   2022-08-30  19:45  Premier League  Matchweek 5  Tue  Away      L  1.0
# 5   2022-09-03  15:00  Premier League  Matchweek 6  Sat  Home      W  2.0
# 8   2022-10-01  15:00  Premier League  Matchweek 9  Sat  Away      W  2.0
# 0   2022-08-23  13:00  Premier League  Matchweek 1  Tue  Home      D  0.0
# 1   2022-08-28  15:00  Premier League  Matchweek 2  Sun  Home      W  1.0
# 2   2022-09-02  17:00  Premier League  Matchweek 3  Fri  Away      W  1.0
# 4   2022-09-10  17:00  Premier League  Matchweek 4  Sat  Home      W  2.0
# 6   2022-10-01  17:00  Premier League  Matchweek 5  Sat  Away      W  6.0
# 1   2022-08-06  12:30  Premier League  Matchweek 1  Sat  Away      D  2.0
# 2   2022-08-15  20:00  Premier League  Matchweek 2  Mon  Home      D  1.0
# 3   2022-08-22  20:00  Premier League  Matchweek 3  Mon  Away      L  1.0
# 4   2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  9.0
# 5   2022-08-31  20:00  Premier League  Matchweek 5  Wed  Home      W  2.0
# 6   2022-09-03  12:30  Premier League  Matchweek 6  Sat  Away      D  0.0
# 9   2022-10-01  15:00  Premier League  Matchweek 9  Sat  Home      D  3.0
# 0   2022-08-06  15:00  Premier League  Matchweek 1  Sat  Home      W  4.0
# 1   2022-08-14  16:30  Premier League  Matchweek 2  Sun  Away      D  2.0
# 2   2022-08-20  12:30  Premier League  Matchweek 3  Sat  Home      W  1.0
# 3   2022-08-28  16:30  Premier League  Matchweek 4  Sun  Away      W  2.0
# 4   2022-08-31  19:45  Premier League  Matchweek 5  Wed  Away      D  1.0
# 5   2022-09-03  15:00  Premier League  Matchweek 6  Sat  Home      W  2.0
# 8   2022-09-17  17:30  Premier League  Matchweek 8  Sat  Home      W  6.0
# 9   2022-10-01  12:30  Premier League  Matchweek 9  Sat  Away      L  1.0
# 0   2022-08-07  14:00  Premier League  Matchweek 1  Sun  Home      D    2
# 1   2022-08-13  15:00  Premier League  Matchweek 2  Sat  Away      L    2
# 2   2022-08-20  15:00  Premier League  Matchweek 3  Sat  Home      L    1
# 4   2022-08-27  15:00  Premier League  Matchweek 4  Sat  Away      L    1
# 5   2022-09-01  20:00  Premier League  Matchweek 5  Thu  Home      L    0
# 6   2022-09-04  14:00  Premier League  Matchweek 6  Sun  Away      L    2
# 7   2022-09-17  17:30  Premier League  Matchweek 8  Sat  Away      L    2
# 8   2022-10-03  20:00  Premier League  Matchweek 9  Mon  Home      W    4
# 0   2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L  0.0
# 1   2022-08-14  14:00  Premier League  Matchweek 2  Sun  Home      W  1.0
# 2   2022-08-20  15:00  Premier League  Matchweek 3  Sat  Away      D  1.0
# 4   2022-08-28  16:30  Premier League  Matchweek 4  Sun  Home      L  0.0
# 5   2022-08-31  19:30  Premier League  Matchweek 5  Wed  Away      L  0.0
# 6   2022-09-03  15:00  Premier League  Matchweek 6  Sat  Home      L  2.0
# 7   2022-09-16  20:00  Premier League  Matchweek 8  Fri  Home      L  2.0
# 8   2022-10-03  20:00  Premier League  Matchweek 9  Mon  Away      L  0.0
#
#      ga                  opponent  ...  match report  notes    sh   sot  dist  \
# 1   0.0                  West Ham  ...  Match Report    NaN  13.0   1.0  18.2
# 2   0.0               Bournemouth  ...  Match Report    NaN  20.0   7.0  15.6
# 3   3.0             Newcastle Utd  ...  Match Report    NaN  22.0  10.0  15.1
# 4   2.0            Crystal Palace  ...  Match Report    NaN  18.0   5.0  13.1
# 5   0.0           Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.1
# 6   1.0               Aston Villa  ...  Match Report    NaN  13.0   4.0  15.7
# 9   0.0                    Wolves  ...  Match Report    NaN  15.0   7.0  18.8
# 10  3.0            Manchester Utd  ...  Match Report    NaN  22.0   9.0  13.5
# 0   0.0                   Everton  ...  Match Report    NaN  14.0   5.0  16.2
# 1   2.0                 Tottenham  ...  Match Report    NaN  16.0   3.0  16.7
# 2   3.0              Leeds United  ...  Match Report    NaN  14.0   3.0  18.8
# 3   1.0            Leicester City  ...  Match Report    NaN   7.0   3.0  13.7
# 4   2.0               Southampton  ...  Match Report    NaN  10.0   4.0  13.8
# 5   1.0                  West Ham  ...  Match Report    NaN   8.0   3.0  16.3
# 8   1.0            Crystal Palace  ...  Match Report    NaN  13.0   3.0  14.0
# 0   0.0  FK Metalist 1925 Kharkiv  ...  Match Report    NaN   NaN   NaN   NaN
# 1   0.0        Kryvbas Kryvyi Rih  ...  Match Report    NaN   NaN   NaN   NaN
# 2   0.0                       Рух  ...  Match Report    NaN   NaN   NaN   NaN
# 4   1.0        Chornomorets Odesa  ...  Match Report    NaN   NaN   NaN   NaN
# 6   1.0       FK Metalist Kharkiv  ...  Match Report    NaN   NaN   NaN   NaN
# 1   2.0                    Fulham  ...  Match Report    NaN  11.0   3.0  11.8
# 2   1.0            Crystal Palace  ...  Match Report    NaN  24.0   4.0  17.1
# 3   2.0            Manchester Utd  ...  Match Report    NaN  17.0   5.0  14.5
# 4   0.0               Bournemouth  ...  Match Report    NaN  19.0  12.0  10.8
# 5   1.0             Newcastle Utd  ...  Match Report    NaN  23.0   6.0  17.4
# 6   0.0                   Everton  ...  Match Report    NaN  24.0   9.0  12.3
# 9   3.0                  Brighton  ...  Match Report    NaN  15.0   7.0  16.0
# 0   1.0               Southampton  ...  Match Report    NaN  18.0   7.0  15.8
# 1   2.0                   Chelsea  ...  Match Report    NaN  10.0   5.0  12.6
# 2   0.0                    Wolves  ...  Match Report    NaN  11.0   5.0  11.0
# 3   0.0           Nott'ham Forest  ...  Match Report    NaN  18.0   4.0  19.0
# 4   1.0                  West Ham  ...  Match Report    NaN  13.0   4.0  16.2
# 5   1.0                    Fulham  ...  Match Report    NaN  23.0  10.0  15.6
# 8   2.0            Leicester City  ...  Match Report    NaN  16.0  10.0  15.8
# 9   3.0                   Arsenal  ...  Match Report    NaN   6.0   2.0  18.8
# 0     2                 Brentford  ...  Match Report    NaN  14.0   5.0  22.2
# 1     4                   Arsenal  ...  Match Report    NaN   6.0   2.0  15.3
# 2     2               Southampton  ...  Match Report    NaN   6.0   1.0  17.1
# 4     2                   Chelsea  ...  Match Report    NaN  17.0   5.0  17.5
# 5     1            Manchester Utd  ...  Match Report    NaN  10.0   2.0  22.6
# 6     5                  Brighton  ...  Match Report    NaN   6.0   4.0  14.3
# 7     6                 Tottenham  ...  Match Report    NaN  18.0   6.0  21.6
# 8     0           Nott'ham Forest  ...  Match Report    NaN  16.0   6.0  16.8
# 0   2.0             Newcastle Utd  ...  Match Report    NaN   5.0   0.0  15.3
# 1   0.0                  West Ham  ...  Match Report    NaN  13.0   6.0  13.5
# 2   1.0                   Everton  ...  Match Report    NaN  14.0   5.0  18.7
# 4   2.0                 Tottenham  ...  Match Report    NaN  18.0   1.0  18.8
# 5   6.0           Manchester City  ...  Match Report    NaN   8.0   1.0  18.9
# 6   3.0               Bournemouth  ...  Match Report    NaN  10.0   2.0  16.9
# 7   3.0                    Fulham  ...  Match Report    NaN  11.0   3.0  15.8
# 8   4.0            Leicester City  ...  Match Report    NaN  10.0   3.0  15.0
#
#      fk   pk pkatt season               team
# 1   1.0  1.0   1.0   2023    Manchester City
# 2   0.0  0.0   0.0   2023    Manchester City
# 3   1.0  0.0   0.0   2023    Manchester City
# 4   0.0  0.0   0.0   2023    Manchester City
# 5   0.0  0.0   0.0   2023    Manchester City
# 6   1.0  0.0   0.0   2023    Manchester City
# 9   0.0  0.0   0.0   2023    Manchester City
# 10  1.0  0.0   0.0   2023    Manchester City
# 0   1.0  1.0   1.0   2023            Chelsea
# 1   0.0  0.0   0.0   2023            Chelsea
# 2   0.0  0.0   0.0   2023            Chelsea
# 3   0.0  0.0   0.0   2023            Chelsea
# 4   0.0  0.0   0.0   2023            Chelsea
# 5   0.0  0.0   0.0   2023            Chelsea
# 8   0.0  0.0   0.0   2023            Chelsea
# 0   NaN  0.0   0.0   2023   Shakhtar Donetsk
# 1   NaN  0.0   0.0   2023   Shakhtar Donetsk
# 2   NaN  0.0   0.0   2023   Shakhtar Donetsk
# 4   NaN  0.0   0.0   2023   Shakhtar Donetsk
# 6   NaN  0.0   1.0   2023   Shakhtar Donetsk
# 1   0.0  0.0   0.0   2022          Liverpool
# 2   0.0  0.0   0.0   2022          Liverpool
# 3   0.0  0.0   0.0   2022          Liverpool
# 4   0.0  0.0   0.0   2022          Liverpool
# 5   0.0  0.0   0.0   2022          Liverpool
# 6   0.0  0.0   0.0   2022          Liverpool
# 9   1.0  0.0   0.0   2022          Liverpool
# 0   0.0  0.0   0.0   2022  Tottenham Hotspur
# 1   0.0  0.0   0.0   2022  Tottenham Hotspur
# 2   0.0  0.0   0.0   2022  Tottenham Hotspur
# 3   0.0  0.0   1.0   2022  Tottenham Hotspur
# 4   0.0  0.0   0.0   2022  Tottenham Hotspur
# 5   1.0  0.0   0.0   2022  Tottenham Hotspur
# 8   0.0  0.0   0.0   2022  Tottenham Hotspur
# 9   0.0  1.0   1.0   2022  Tottenham Hotspur
# 0   0.0  0.0   0.0   2021     Leicester City
# 1   0.0  0.0   0.0   2021     Leicester City
# 2   1.0  0.0   0.0   2021     Leicester City
# 4   0.0  0.0   0.0   2021     Leicester City
# 5   2.0  0.0   0.0   2021     Leicester City
# 6   0.0  0.0   0.0   2021     Leicester City
# 7   0.0  1.0   1.0   2021     Leicester City
# 8   1.0  0.0   0.0   2021     Leicester City
# 0   0.0  0.0   0.0   2021  Nottingham Forest
# 1   1.0  0.0   0.0   2021  Nottingham Forest
# 2   1.0  0.0   0.0   2021  Nottingham Forest
# 4   1.0  0.0   0.0   2021  Nottingham Forest
# 5   1.0  0.0   0.0   2021  Nottingham Forest
# 6   0.0  1.0   1.0   2021  Nottingham Forest
# 7   1.0  0.0   0.0   2021  Nottingham Forest
# 8   0.0  0.0   0.0   2021  Nottingham Forest
#
# [51 rows x 27 columns]

# %%
# match_df.to_csv("matches.csv")

# %%
import pandas as pd
import numpy as np

# %%
foodBalance_df = pd.read_csv('D:/Hamoye/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')
foodBalance_df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
foodBalance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
foodBalance_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
foodBalance_df.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
foodBalance_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(foodBalance_df.isnull())
# Out:
# <AxesSubplot:>

# %%
foodBalance_df.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %% [markdown]
# # Checking For Duplicated Rows

# %%
foodBalance_df[foodBalance_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Element, Unit, Y2014, Y2015, Y2016, Y2017, Y2018]
# Index: []

# %% [markdown]
# # Exploratory Analysis

# %%
foodBalance_df['Y2014'].min(),foodBalance_df['Y2014'].max()
# Out:
# (-1796.0, 176405.0)

# %%
foodBalance_df['Y2015'].min(),foodBalance_df['Y2015'].max()
# Out:
# (-3161.0, 181137.0)

# %%
foodBalance_df['Y2016'].min(),foodBalance_df['Y2016'].max()
# Out:
# (-3225.0, 185960.0)

# %%
foodBalance_df['Y2017'].min(),foodBalance_df['Y2017'].max()
# Out:
# (-1582.0, 190873.0)

# %%
foodBalance_df.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
foodBalance_df.Area.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
foodBalance_df['Element'].value_counts()
# Out:
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: Element, dtype: int64

# %%
foodBalance_df.head(1)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0

# %%
foodBalance_df.groupby('Element').sum().sort_values(by=['Y2018'])
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Tourist consumption                         50308    1486528       2869905
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Protein supply quantity (g/capita/day)     675050   13535000       3385502
# Stock Variation                            571566   11329527      21464704
# Seed                                       103537    2035933       4211574
# Residuals                                  623271   12421089      24066350
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Other uses (non-food)                      235554    4729749       8926728
# Losses                                     274353    5424803      10292107
# Export Quantity                            599910   11840553      26026133
# Feed                                       176272    3538507       7282199
# ...

# %%
foodBalance_df.groupby(['Element','Y2018']).max()
# Out:
#                                  Area Code                   Area  Item Code  \
# Element                  Y2018
# Domestic supply quantity -184.0         81                  Ghana       2912
#                          -175.0        202           South Africa       2657
#                          -148.0        202           South Africa       2928
#                          -143.0        202           South Africa       2899
#                          -89.0          81                  Ghana       2586
# ...                                    ...                    ...        ...
# Tourist consumption       1.0          137              Mauritius       2948
#                           2.0          193  Sao Tome and Principe       2948
#                           3.0          137              Mauritius       2918
#                           4.0          193  Sao Tome and Principe       2905
#                           6.0          193  Sao Tome and Principe       2914
#
# ...

# %%
foodBalance_df['Y2018'].max()
# Out:
# 195875.0

# %%
foodBalance_df.head(1)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0

# %%
foodBalance_df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
foodBalance_df['Y2014'].sum(),foodBalance_df['Y2015'].sum(),foodBalance_df['Y2016'].sum(),foodBalance_df['Y2017'].sum(),foodBalance_df['Y2018'].sum()
# Out:
# (7965086.130000001,
#  8032340.2299999995,
#  8112472.649999999,
#  8375729.189999999,
#  8554629.96)

# %%
foodBalance_df.sum()
# Out:
# Area Code                                                 8182547
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                               163764610
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                            232488797
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                  7965086.13
# Y2015                                                  8032340.23
# Y2016                                                  8112472.65
# Y2017                                                  8375729.19
# Y2018                                                  8554629.96
# dtype: object

# %%
foodBalance_df.head(1)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0

# %%
foodBalance_df.groupby('Element Code').corr().sum()
# Out:
# Area Code    18.493731
# Item Code    25.835666
# Y2014        86.012975
# Y2015        85.248146
# Y2016        87.093281
# Y2017        86.958780
# Y2018        86.516790
# dtype: float64

# %% [markdown]
# # Mean and Std for 2015

# %%
foodBalance_df['Y2015'].mean(),foodBalance_df['Y2015'].std()
# Out:
# (135.23596649549236, 1603.4039839423301)

# %% [markdown]
# # Total number and Missing percentage data

# %%
foodBalance_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# # Sum

# %%
foodBalance_df['Y2014'].isnull().sum()+foodBalance_df['Y2015'].isnull().sum()+foodBalance_df['Y2016'].isnull().sum()+foodBalance_df['Y2017'].isnull().sum()+foodBalance_df['Y2018'].isnull().sum()
# Out:
# 7614

# %% [markdown]
# # 2016

# %%
foodBalance_df['Y2016'].isnull().sum()
# Out:
# 1535

# %% [markdown]
# # Percentage

# %%
foodBalance_df['Y2014'].isnull().sum()/len(foodBalance_df['Y2014'])
# Out:
# 0.026073544131401474

# %%
foodBalance_df['Y2014'].isnull().sum()/1535 * 100
# Out:
# 103.51791530944625

# %% [markdown]
# # 2016

# %%
foodBalance_df['Y2016'].isnull().sum()/1535
# Out:
# 1.0

# %% [markdown]
# # Total sum of Animal fat

# %%
foodBalance_df.head(1)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0

# %%
foodBalance_df.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
foodBalance_df.shape
# Out:
# (60943, 12)
